# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_retail_data = pd.read_csv("retail dataset/retail_data_W23 - retail_data_W23.csv")
df_retail_order = pd.read_excel("retail dataset/retail_orders_W23.xlsx")
df_retail_store = pd.read_excel("retail dataset/store.xlsx")

# %%
df_retail_data
# Out:
#         Store  DayOfWeek        Date  Customers  Open  Promo StateHoliday  \
# 0           3          5  2015-07-31        821     1      1            0
# 1           4          5  2015-07-31       1498     1      1            0
# 2           5          5  2015-07-31        559     1      1            0
# 3           6          5  2015-07-31        589     1      1            0
# 4          10          5  2015-07-31        681     1      1            0
# ...       ...        ...         ...        ...   ...    ...          ...
# 651008   1106          2  2013-01-01          0     0      0            a
# 651009   1109          2  2013-01-01          0     0      0            a
# 651010   1112          2  2013-01-01          0     0      0            a
# 651011   1113          2  2013-01-01          0     0      0            a
# 651012   1114          2  2013-01-01          0     0      0            a
#
#         SchoolHoliday        Id
# 0                   1       409
# ...

# %%
df_retail_data.describe()
# Out:
#                Store      DayOfWeek      Customers           Open  \
# count  651013.000000  651013.000000  651013.000000  651013.000000
# mean      558.645629       3.999336     632.851832       0.829619
# std       321.905872       1.998260     464.857658       0.375967
# min         1.000000       1.000000       0.000000       0.000000
# 25%       281.000000       2.000000     404.000000       1.000000
# 50%       558.000000       4.000000     609.000000       1.000000
# 75%       838.000000       6.000000     837.000000       1.000000
# max      1115.000000       7.000000    5458.000000       1.000000
#
#                Promo  SchoolHoliday            Id
# count  651013.000000  651013.000000  6.510130e+05
# mean        0.381558       0.178927  9.153619e+06
# std         0.485769       0.383292  5.285944e+06
# min         0.000000       0.000000  4.090000e+02
# 25%         0.000000       0.000000  4.578709e+06
# 50%         0.000000       0.000000  9.151915e+06
# ...

# %%
df_retail_order.describe()
# Out:
#                  Id         Orders
# count  6.510130e+05  651013.000000
# mean   9.153619e+06    5770.521006
# std    5.285944e+06    3851.171979
# min    4.090000e+02       0.000000
# 25%    4.578709e+06    3721.000000
# 50%    9.151915e+06    5743.000000
# 75%    1.373353e+07    7856.000000
# max    1.831010e+07   38722.000000

# %%
df_retail_data['Id'] == df_retail_order['Id']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 651008    True
# 651009    True
# 651010    True
# 651011    True
# 651012    True
# Name: Id, Length: 651013, dtype: bool

# %%
df_retail_data['Orders'] = df_retail_order['Orders']

# %%
df_retail_data
# Out:
#         Store  DayOfWeek        Date  Customers  Open  Promo StateHoliday  \
# 0           3          5  2015-07-31        821     1      1            0
# 1           4          5  2015-07-31       1498     1      1            0
# 2           5          5  2015-07-31        559     1      1            0
# 3           6          5  2015-07-31        589     1      1            0
# 4          10          5  2015-07-31        681     1      1            0
# ...       ...        ...         ...        ...   ...    ...          ...
# 651008   1106          2  2013-01-01          0     0      0            a
# 651009   1109          2  2013-01-01          0     0      0            a
# 651010   1112          2  2013-01-01          0     0      0            a
# 651011   1113          2  2013-01-01          0     0      0            a
# 651012   1114          2  2013-01-01          0     0      0            a
#
#         SchoolHoliday        Id   Orders
# ...

# %%
df_retail_data.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# Id               0
# Orders           0
# dtype: int64

# %%
df_retail_data.nunique(axis=0)
# Out:
# Store              1115
# DayOfWeek             7
# Date                942
# Customers          3915
# Open                  2
# Promo                 2
# StateHoliday          4
# SchoolHoliday         2
# Id               651013
# Orders            20206
# dtype: int64

# %%
corrr_matrix = df_retail_data.corr()

# %%
sns.heatmap(corrr_matrix, annot= True)
plt.show()

# %%
df_retail_store
# Out:
#        Store StoreType Assortment  CompetitionDistance  \
# 0        1.0         c          a               1270.0
# 1        2.0         a          a                570.0
# 2        3.0         a          a              14130.0
# 3        4.0         c          c                620.0
# 4        5.0         a          a              29910.0
# ...      ...       ...        ...                  ...
# 1110  1111.0         a          a               1900.0
# 1111  1112.0         c          c               1880.0
# 1112  1113.0         a          c               9260.0
# 1113  1114.0         a          c                870.0
# 1114  1115.0         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0     0.0
# 1                          11.0                    2007.0     1.0
# 2                          12.0                    2006.0     1.0
# ...

# %%
df_retail_store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
df_store_data = df_retail_store.dropna()

# %%
df_store_data.isnull().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
df_store_data
# Out:
#        Store StoreType Assortment  CompetitionDistance  \
# 1        2.0         a          a                570.0
# 2        3.0         a          a              14130.0
# 10      11.0         a          c                960.0
# 13      14.0         a          a               1300.0
# 14      15.0         d          c               4110.0
# ...      ...       ...        ...                  ...
# 1104  1105.0         c          c                330.0
# 1105  1106.0         a          c               5330.0
# 1106  1107.0         a          a               1400.0
# 1108  1109.0         c          a               3490.0
# 1110  1111.0         a          a               1900.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 1                          11.0                    2007.0     1.0
# 2                          12.0                    2006.0     1.0
# 10                         11.0                    2011.0     1.0
# ...

# %%
sns.heatmap(
    df_store_data.corr(),
    annot= True
)
plt.show()

# %%
df_store_data.drop(columns=['Promo2'], axis=1, inplace= True)
# Out:
# C:\Users\vismi\AppData\Local\Temp\ipykernel_40596\2124403610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_store_data.drop(columns=['Promo2'], axis=1, inplace= True)

# %%
pd.merge(df_retail_data, df_store_data, on='Store', how= 'left')
# Out:
#         Store  DayOfWeek        Date  Customers  Open  Promo StateHoliday  \
# 0           3          5  2015-07-31        821     1      1            0
# 1           4          5  2015-07-31       1498     1      1            0
# 2           5          5  2015-07-31        559     1      1            0
# 3           6          5  2015-07-31        589     1      1            0
# 4          10          5  2015-07-31        681     1      1            0
# ...       ...        ...         ...        ...   ...    ...          ...
# 651008   1106          2  2013-01-01          0     0      0            a
# 651009   1109          2  2013-01-01          0     0      0            a
# 651010   1112          2  2013-01-01          0     0      0            a
# 651011   1113          2  2013-01-01          0     0      0            a
# 651012   1114          2  2013-01-01          0     0      0            a
#
#         SchoolHoliday        Id   Orders StoreType Assortment  \
# ...

# %%
df_retail_data
# Out:
#         Store  DayOfWeek        Date  Customers  Open  Promo StateHoliday  \
# 0           3          5  2015-07-31        821     1      1            0
# 1           4          5  2015-07-31       1498     1      1            0
# 2           5          5  2015-07-31        559     1      1            0
# 3           6          5  2015-07-31        589     1      1            0
# 4          10          5  2015-07-31        681     1      1            0
# ...       ...        ...         ...        ...   ...    ...          ...
# 651008   1106          2  2013-01-01          0     0      0            a
# 651009   1109          2  2013-01-01          0     0      0            a
# 651010   1112          2  2013-01-01          0     0      0            a
# 651011   1113          2  2013-01-01          0     0      0            a
# 651012   1114          2  2013-01-01          0     0      0            a
#
#         SchoolHoliday        Id   Orders
# ...

# %%
type(df_retail_data.loc[1])
# Out:
# pandas.core.series.Series

# %%
def combine_frames (df1, df2):
